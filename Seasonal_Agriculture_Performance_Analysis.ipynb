# %% [markdown]
# #Seasonal Agriculture Performance Analysis
# ### VOIS AICTE Major Project — Batch 1, 2026–2027
#
# **Student:** Anirudra Gupta &nbsp;&nbsp;
#
# **College:** MediCaps University, Indore &nbsp;&nbsp;
#
# **Program:** B.Tech CSE
#
# **Objective:** To study how agricultural performance (yield, profit, resource use) changes across
# the three farming seasons — Kharif, Rabi, and Zaid — using basic data analytics techniques.

# %% [markdown]
# ##**Seasonal Agriculture Performance Analysis**
#
# ##**Major Data Analytics Project**
#
# **Domain** : Agriculture
#
# **Project Theme** : Seasonal Agriculture Performance
#
# **tools** : Pyhton , Numpy , Pandas, MatplotLib , Seaborn
#
# **Project Goal** : Investigate how agricultural performance varies across seasons and identify meaningful patterns and trends , relationships and differences in the available data.

# %% [markdown]
# **1. Problem Statement**
#
# Agricultural activities are influenced by seasonal variations in environmental conditions,
# farming practices, resource availability and market conditions. As a result, agricultural
# performance may differ from one season to another.
# However, raw agricultural data does not clearly explain how agricultural performance changes
# across seasons or what patterns can be observed in different seasonal conditions.
# The problem is to analyze the given agricultural dataset and investigate seasonal differences
# in agricultural performance by identifying meaningful patterns, trends, relationships and
# variations within the available data.

# %% [markdown]
# **2. Project Objectives**
#
# The primary objective of this project is to analyze agricultural data from different seasons
# and identify meaningful patterns, trends, relationships and differences in agricultural
# performance.
#
#
#
# *   Explore and understand the dataset.
# *   Clean and prepare the data for analysis.
# *   Examine how agricultural performance varies across seasons.
# *   Identify important seasonal patterns and trends.
# *   Investigate relationships between seasonal conditions and agricultural outcomes.
# *   Compare relevant groups within different seasons.
# *   Identify significant differences or unusual patterns.
# *   Apply appropriate statistical and visualization techniques.
# *   Interpret findings based on evidence from the dataset.
# *   Develop meaningful conclusions and data-driven recommendations.

# %% [markdown]
# **3. Dataset**
#
# The dataset represents agricultural activities carried out across different seasons,
# geographical areas and farming conditions. It contains information related to farming
# practices, environmental conditions, crop production, resource usage and economic
# performance.
#
#
# The dataset provides students with an opportunity to explore how agricultural performance
# changes across seasons and to identify meaningful patterns and differences through data
# analysis.
#
# **Dataset File** : /content/seasonal_agriculture_performance_dataset.xlsx

# %% [markdown]
# ##Step 1: Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries imported successfully")

# %matplotlib inline
sns.set_theme(style="whitegrid")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option("display.float_format", lambda x: f"(x:,.2f)")
# Out:
# Libraries imported successfully

# %% [markdown]
# This cell imports the necessary Python libraries for data manipulation (`pandas`, `numpy`), and data visualization (`matplotlib.pyplot`, `seaborn`). These libraries are standard tools for data analysis in Python.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

file_path = '/content/seasonal_agriculture_performance_dataset.xlsx'
df = pd.read_excel(file_path)
print(df)
# Out:
#       Farm_ID           State  District       Crop  Season  \
# 0     SF10001  Andhra Pradesh    Rajkot      Wheat  Kharif
# 1     SF10002     Maharashtra  Nalgonda      Maize  Kharif
# 2     SF10003       Telangana  Warangal     Pulses    Rabi
# 3     SF10004       Telangana    Indore       Rice  Kharif
# 4     SF10005       Karnataka  Ludhiana      Maize    Zaid
# 5     SF10006         Gujarat   Raichur     Pulses    Zaid
# 6     SF10007       Telangana  Warangal      Wheat    Rabi
# 7     SF10008      Tamil Nadu  Ludhiana     Pulses  Kharif
# 8     SF10009       Karnataka    Guntur     Cotton    Zaid
# 9     SF10010      Tamil Nadu   Raichur     Chilli    Rabi
# 10    SF10011     Maharashtra   Krishna      Wheat    Rabi
# 11    SF10012       Telangana    Rajkot      Maize    Rabi
# 12    SF10013          Punjab    Indore      Wheat    Rabi
# 13    SF10014         Gujarat    Indore     Pulses  Kharif
# 14    SF10015          Punjab    Indore       Rice  Kharif
# ...

# %% [markdown]
# ## Step 2: Load the Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

file_path = '/content/seasonal_agriculture_performance_dataset.xlsx'
df = pd.read_excel(file_path)
print(df)
print("Dataset loaded successfully!")
# Out:
#       Farm_ID           State  District       Crop  Season  \
# 0     SF10001  Andhra Pradesh    Rajkot      Wheat  Kharif
# 1     SF10002     Maharashtra  Nalgonda      Maize  Kharif
# 2     SF10003       Telangana  Warangal     Pulses    Rabi
# 3     SF10004       Telangana    Indore       Rice  Kharif
# 4     SF10005       Karnataka  Ludhiana      Maize    Zaid
# 5     SF10006         Gujarat   Raichur     Pulses    Zaid
# 6     SF10007       Telangana  Warangal      Wheat    Rabi
# 7     SF10008      Tamil Nadu  Ludhiana     Pulses  Kharif
# 8     SF10009       Karnataka    Guntur     Cotton    Zaid
# 9     SF10010      Tamil Nadu   Raichur     Chilli    Rabi
# 10    SF10011     Maharashtra   Krishna      Wheat    Rabi
# 11    SF10012       Telangana    Rajkot      Maize    Rabi
# 12    SF10013          Punjab    Indore      Wheat    Rabi
# 13    SF10014         Gujarat    Indore     Pulses  Kharif
# 14    SF10015          Punjab    Indore       Rice  Kharif
# ...

# %% [markdown]
# This code block loads the `seasonal_agriculture_performance_dataset.xlsx` file into a pandas DataFrame named `df`. It then prints a confirmation message and displays the entire DataFrame to show the loaded data.

# %% [markdown]
# ## Step 3: Initial Data Understanding

# %% [markdown]
# **df.head() — shows the first 5 rows**

# %%
df.head()
# Out:
#    Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 0  SF10001  Andhra Pradesh    Rajkot   Wheat  Kharif            (x:,.2f)
# 1  SF10002     Maharashtra  Nalgonda   Maize  Kharif            (x:,.2f)
# 2  SF10003       Telangana  Warangal  Pulses    Rabi            (x:,.2f)
# 3  SF10004       Telangana    Indore    Rice  Kharif            (x:,.2f)
# 4  SF10005       Karnataka  Ludhiana   Maize    Zaid            (x:,.2f)
#
#    Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  Soil_pH  \
# 0     (x:,.2f)           (x:,.2f)      (x:,.2f)            (x:,.2f) (x:,.2f)
# 1     (x:,.2f)           (x:,.2f)      (x:,.2f)            (x:,.2f) (x:,.2f)
# 2     (x:,.2f)           (x:,.2f)      (x:,.2f)            (x:,.2f) (x:,.2f)
# 3     (x:,.2f)           (x:,.2f)      (x:,.2f)            (x:,.2f) (x:,.2f)
# 4     (x:,.2f)           (x:,.2f)      (x:,.2f)            (x:,.2f) (x:,.2f)
#
# ...

# %% [markdown]
# This command displays the first 5 rows of the DataFrame `df`. This is a quick way to get a glimpse of the data's structure, column names, and initial values.

# %% [markdown]
# **df.tail() — shows the last 5 rows**

# %%
df.tail()
# Out:
#       Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 3995  SF13996       Karnataka    Rajkot   Wheat  Kharif            (x:,.2f)
# 3996  SF13997       Karnataka   Krishna  Chilli  Kharif            (x:,.2f)
# 3997  SF13998  Andhra Pradesh     Erode  Pulses    Zaid            (x:,.2f)
# 3998  SF13999          Punjab  Warangal  Cotton  Kharif            (x:,.2f)
# 3999  SF14000          Punjab    Nashik   Wheat  Kharif            (x:,.2f)
#
#       Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  \
# 3995     (x:,.2f)           (x:,.2f)      (x:,.2f)            (x:,.2f)
# 3996     (x:,.2f)           (x:,.2f)      (x:,.2f)            (x:,.2f)
# 3997     (x:,.2f)           (x:,.2f)      (x:,.2f)            (x:,.2f)
# 3998     (x:,.2f)           (x:,.2f)      (x:,.2f)            (x:,.2f)
# 3999     (x:,.2f)           (x:,.2f)      (x:,.2f)            (x:,.2f)
#
#       Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  Phosphorus_kg_ha  \
# ...

# %% [markdown]
# This command displays the last 5 rows of the DataFrame `df`. It's useful for checking the end of the dataset and ensuring data was loaded completely, similar to `df.head()`.

# %% [markdown]
# **df.sample(5) — shows 5 random rows**

# %%
df.sample(5)
# Out:
#       Farm_ID           State District       Crop  Season  Farm_Area_Hectares  \
# 3777  SF13778          Punjab   Guntur     Chilli  Kharif            (x:,.2f)
# 578   SF10579  Andhra Pradesh   Indore      Wheat  Kharif            (x:,.2f)
# 1750  SF11751       Karnataka   Rajkot     Cotton    Zaid            (x:,.2f)
# 796   SF10797         Gujarat   Guntur  Sugarcane    Zaid            (x:,.2f)
# 1805  SF11806      Tamil Nadu   Guntur     Chilli  Kharif            (x:,.2f)
#
#       Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  \
# 3777     (x:,.2f)           (x:,.2f)      (x:,.2f)            (x:,.2f)
# 578      (x:,.2f)           (x:,.2f)      (x:,.2f)            (x:,.2f)
# 1750     (x:,.2f)           (x:,.2f)      (x:,.2f)            (x:,.2f)
# 796      (x:,.2f)           (x:,.2f)      (x:,.2f)            (x:,.2f)
# 1805     (x:,.2f)           (x:,.2f)      (x:,.2f)            (x:,.2f)
#
#       Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  Phosphorus_kg_ha  \
# ...

# %% [markdown]
# This command displays 5 random rows from the DataFrame `df`. This helps to get a more generalized view of the data by sampling different parts of the dataset.

# %% [markdown]
# **df.shape — number of rows and columns**

# %%
df.shape
# Out:
# (4000, 28)

# %% [markdown]
# This command returns a tuple representing the dimensions of the DataFrame, specifically the number of rows and columns. It's essential for understanding the size of the dataset.

# %% [markdown]
# **df.columns — list of all column names**

# %%
df.columns
# Out:
# Index(['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Farm_Area_Hectares',
#        'Rainfall_mm', 'Avg_Temperature_C', 'Humidity_pct',
#        'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct', 'Nitrogen_kg_ha',
#        'Phosphorus_kg_ha', 'Potassium_kg_ha', 'Irrigation_Method',
#        'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score',
#        'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne',
#        'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3',
#        'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct'],
#       dtype='object')

# %% [markdown]
# This command displays a list of all column names in the DataFrame. This is useful for identifying available features and for subsequent data manipulation.

# %% [markdown]
# **df.dtypes — data type of each column**

# %%
df.dtypes
# Out:
# Farm_ID                           object
# State                             object
# District                          object
# Crop                              object
# Season                            object
# Farm_Area_Hectares               float64
# Rainfall_mm                      float64
# Avg_Temperature_C                float64
# Humidity_pct                     float64
# Sunlight_Hours_Day               float64
# Soil_pH                          float64
# Soil_Moisture_pct                float64
# Nitrogen_kg_ha                   float64
# Phosphorus_kg_ha                 float64
# Potassium_kg_ha                  float64
# Irrigation_Method                 object
# Fertilizer_kg_ha                 float64
# Pesticide_Litre_ha               float64
# Seed_Quality_Score               float64
# Yield_Tonnes_Ha                  float64
# Production_Tonnes                float64
# Market_Price_INR_Tonne             int64
# Total_Cost_INR                     int64
# ...

# %% [markdown]
# This command shows the data type of each column in the DataFrame. Understanding data types is crucial for data cleaning, type conversion, and ensuring appropriate operations can be performed on each column.

# %% [markdown]
# **df.info() — summary of the dataframe**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Farm_ID                        4000 non-null   object
#  1   State                          4000 non-null   object
#  2   District                       4000 non-null   object
#  3   Crop                           4000 non-null   object
#  4   Season                         4000 non-null   object
#  5   Farm_Area_Hectares             4000 non-null   float64
#  6   Rainfall_mm                    3952 non-null   float64
#  7   Avg_Temperature_C              4000 non-null   float64
#  8   Humidity_pct                   4000 non-null   float64
#  9   Sunlight_Hours_Day             4000 non-null   float64
#  10  Soil_pH                        4000 non-null   float64
#  11  Soil_Moisture_pct              3960 non-null   float64
# ...

# %% [markdown]
# This command prints a concise summary of the DataFrame, including the number of entries, the number of non-null values for each column, and their data types. It also shows memory usage. This helps in quickly identifying columns with missing values and confirming data types.

# %% [markdown]
# **df.describe() — basic statistics of numeric columns**

# %%
df.describe()
# Out:
#        Farm_Area_Hectares  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# count            (x:,.2f)     (x:,.2f)           (x:,.2f)      (x:,.2f)
# mean             (x:,.2f)     (x:,.2f)           (x:,.2f)      (x:,.2f)
# std              (x:,.2f)     (x:,.2f)           (x:,.2f)      (x:,.2f)
# min              (x:,.2f)     (x:,.2f)           (x:,.2f)      (x:,.2f)
# 25%              (x:,.2f)     (x:,.2f)           (x:,.2f)      (x:,.2f)
# 50%              (x:,.2f)     (x:,.2f)           (x:,.2f)      (x:,.2f)
# 75%              (x:,.2f)     (x:,.2f)           (x:,.2f)      (x:,.2f)
# max              (x:,.2f)     (x:,.2f)           (x:,.2f)      (x:,.2f)
#
#        Sunlight_Hours_Day  Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  \
# count            (x:,.2f) (x:,.2f)           (x:,.2f)        (x:,.2f)
# mean             (x:,.2f) (x:,.2f)           (x:,.2f)        (x:,.2f)
# std              (x:,.2f) (x:,.2f)           (x:,.2f)        (x:,.2f)
# ...

# %% [markdown]
# ## Step 4: Check for Missing Values and Duplicates

# %% [markdown]
# **df.isnull().sum() — count missing values in each column**

# %%
df.isnull().sum()
# Out:
# Farm_ID                           0
# State                             0
# District                          0
# Crop                              0
# Season                            0
# Farm_Area_Hectares                0
# Rainfall_mm                      48
# Avg_Temperature_C                 0
# Humidity_pct                      0
# Sunlight_Hours_Day                0
# Soil_pH                           0
# Soil_Moisture_pct                40
# Nitrogen_kg_ha                    0
# Phosphorus_kg_ha                  0
# Potassium_kg_ha                   0
# Irrigation_Method                 0
# Fertilizer_kg_ha                  0
# Pesticide_Litre_ha                0
# Seed_Quality_Score                0
# Yield_Tonnes_Ha                  32
# Production_Tonnes                 0
# Market_Price_INR_Tonne            0
# Total_Cost_INR                    0
# Revenue_INR                       0
# Profit_INR                        0
# Water_Used_m3                     0
# ...

# %% [markdown]
# This code calculates the number of missing (null) values in each column of the DataFrame. `isnull()` identifies nulls, and `sum()` counts them per column. This helps identify columns that need missing value imputation.

# %% [markdown]
# **df.duplicated().sum() — count duplicate rows**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# This command counts the number of duplicate rows in the DataFrame. Identifying and handling duplicates is an important step in data cleaning to ensure data integrity.

# %% [markdown]
# ## Step 5: Clean the Data

# %% [markdown]
# Fill missing values with the average (mean) of that column.

# %%
df['Rainfall_mm'] = df['Rainfall_mm'].fillna(df['Rainfall_mm'].mean())
df['Soil_Moisture_pct'] = df['Soil_Moisture_pct'].fillna(df['Soil_Moisture_pct'].mean())
df['Yield_Tonnes_Ha'] = df['Yield_Tonnes_Ha'].fillna(df['Yield_Tonnes_Ha'].mean())

print("Missing values filled")
df.isnull().sum()
# Out:
# Missing values filled
# Farm_ID                          0
# State                            0
# District                         0
# Crop                             0
# Season                           0
# Farm_Area_Hectares               0
# Rainfall_mm                      0
# Avg_Temperature_C                0
# Humidity_pct                     0
# Sunlight_Hours_Day               0
# Soil_pH                          0
# Soil_Moisture_pct                0
# Nitrogen_kg_ha                   0
# Phosphorus_kg_ha                 0
# Potassium_kg_ha                  0
# Irrigation_Method                0
# Fertilizer_kg_ha                 0
# Pesticide_Litre_ha               0
# Seed_Quality_Score               0
# Yield_Tonnes_Ha                  0
# Production_Tonnes                0
# Market_Price_INR_Tonne           0
# Total_Cost_INR                   0
# Revenue_INR                      0
# Profit_INR                       0
# Water_Used_m3                    0
# ...

# %% [markdown]
# This code fills the missing values (`NaN`) in the 'Rainfall_mm', 'Soil_Moisture_pct', and 'Yield_Tonnes_Ha' columns with the mean (average) of their respective columns. This is a common strategy for handling numerical missing data, maintaining the central tendency of the data. It then re-checks for missing values.

# %% [markdown]
# Check again to confirm there are no missing values left.

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# This command confirms that all missing values have been handled by summing the count of nulls across all columns. A result of 0 indicates no remaining missing values.

# %% [markdown]
# ## Step 6: Explore the Columns

# %% [markdown]
# **df['Season'].unique() — see the different seasons in the dataset**

# %%
df['Season'].unique()
# Out:
# array(['Kharif', 'Rabi', 'Zaid'], dtype=object)

# %% [markdown]
# This command returns an array of all unique values present in the 'Season' column. This helps in understanding the different categories of seasons available in the dataset.

# %% [markdown]
# **df['Season'].value_counts() — count how many rows belong to each season**

# %%
df['Season'].value_counts()
# Out:
# Season
# Kharif    1779
# Rabi      1627
# Zaid       594
# Name: count, dtype: int64

# %% [markdown]
# This command counts the occurrences of each unique value in the 'Season' column, showing how many farms belong to each season. This provides a distribution of the data across seasons.

# %% [markdown]
# **df['Crop'].unique() — see the different crops**

# %%
df['Crop'].unique()
# Out:
# array(['Wheat', 'Maize', 'Pulses', 'Rice', 'Cotton', 'Chilli',
#        'Groundnut', 'Sugarcane'], dtype=object)

# %% [markdown]
# This command returns an array of all unique crop types present in the 'Crop' column. It helps to identify the variety of crops included in the dataset.

# %% [markdown]
# **df['State'].unique() — see the different states**

# %%
df['State'].unique()
# Out:
# array(['Andhra Pradesh', 'Maharashtra', 'Telangana', 'Karnataka',
#        'Gujarat', 'Tamil Nadu', 'Punjab', 'Madhya Pradesh'], dtype=object)

# %% [markdown]
# This command returns an array of all unique state names present in the 'State' column, showing the different geographical regions covered by the dataset.

# %% [markdown]
# ## Step 7: Basic Visualization — Season Distribution

# %%
df['Season'].value_counts().plot(kind='bar', color=['blue','green','orange'])
plt.title('Number of Farms in Each Season')
plt.xlabel('Season')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This code generates a bar plot showing the number of farms in each season. `value_counts()` gets the counts, and `.plot(kind='bar')` visualizes them. It provides a visual representation of the seasonal distribution of farms.

# %% [markdown]
# ## Step 8: Average Values Season-Wise
#
# **groupby() — group the data by Season and find the average of other columns**

# %%
df.groupby('Season')['Yield_Tonnes_Ha'].mean()
# Out:
# Season
# Kharif   (x:,.2f)
# Rabi     (x:,.2f)
# Zaid     (x:,.2f)
# Name: Yield_Tonnes_Ha, dtype: float64

# %% [markdown]
# This command groups the DataFrame by 'Season' and then calculates the mean of 'Yield_Tonnes_Ha' for each season. This helps in understanding the average yield performance across different agricultural seasons.

# %%
df.groupby('Season')['Profit_INR'].mean()
# Out:
# Season
# Kharif   (x:,.2f)
# Rabi     (x:,.2f)
# Zaid     (x:,.2f)
# Name: Profit_INR, dtype: float64

# %% [markdown]
# This command groups the DataFrame by 'Season' and calculates the mean 'Profit_INR' for each season. This helps in comparing the average profitability of farming activities in different seasons.

# %%
df.groupby('Season')['Rainfall_mm'].mean()
# Out:
# Season
# Kharif   (x:,.2f)
# Rabi     (x:,.2f)
# Zaid     (x:,.2f)
# Name: Rainfall_mm, dtype: float64

# %% [markdown]
# This command groups the DataFrame by 'Season' and calculates the mean 'Rainfall_mm' for each season. This provides insights into the average rainfall patterns experienced during different agricultural seasons.

# %%
df.groupby('Season')['Water_Used_m3'].mean()
# Out:
# Season
# Kharif   (x:,.2f)
# Rabi     (x:,.2f)
# Zaid     (x:,.2f)
# Name: Water_Used_m3, dtype: float64

# %% [markdown]
# This command groups the DataFrame by 'Season' and calculates the mean 'Water_Used_m3' for each season. This helps in understanding the average water consumption across different agricultural seasons.

# %% [markdown]
# ## Step 9: Visualize Season-Wise Averages

# %% [markdown]
# **Bar chart — Average Yield by Season**

# %%
df.groupby('Season')['Yield_Tonnes_Ha'].mean().plot(kind='bar', color='green')
plt.title('Average Yield (Tonnes/Ha) by Season')
plt.ylabel('Yield (Tonnes/Ha)')
plt.show()

# %% [markdown]
# This code generates a bar chart to visualize the average 'Yield_Tonnes_Ha' for each season. It makes it easy to compare yield performance visually across seasons.

# %% [markdown]
# **Bar chart — Average Profit by Season**

# %%
df.groupby('Season')['Profit_INR'].mean().plot(kind='bar', color='orange')
plt.title('Average Profit (INR) by Season')
plt.ylabel('Profit (INR)')
plt.axhline(0, color='black')
plt.show()

# %% [markdown]
# This code generates a bar chart to visualize the average 'Profit_INR' for each season. The horizontal line at 0 helps to quickly identify seasons where average profit is negative (loss-making).

# %% [markdown]
# **Bar chart — Average Rainfall by Season**

# %%
df.groupby('Season')['Rainfall_mm'].mean().plot(kind='bar', color='blue')
plt.title('Average Rainfall (mm) by Season')
plt.ylabel('Rainfall (mm)')
plt.show()

# %% [markdown]
# This code generates a bar chart to visualize the average 'Rainfall_mm' for each season. It provides a visual comparison of rainfall levels across the different agricultural seasons.

# %% [markdown]
# ## Step 10: Boxplot to Compare Yield Across Seasons

# %%
sns.boxplot(x='Season', y='Yield_Tonnes_Ha', data=df)
plt.title('Yield Distribution by Season')
plt.show()

# %% [markdown]
# This code uses a boxplot to display the distribution of 'Yield_Tonnes_Ha' for each 'Season'. Boxplots are excellent for showing the median, quartiles, and potential outliers, allowing for a detailed comparison of yield variability across seasons.

# %% [markdown]
# ## Step 11: Boxplot to Compare Profit Across Seasons

# %%
sns.boxplot(x='Season', y='Profit_INR', data=df)
plt.title('Profit Distribution by Season')
plt.axhline(0, color='black', linestyle='--')
plt.show()

# %% [markdown]
# This code uses a boxplot to display the distribution of 'Profit_INR' for each 'Season'. The horizontal dashed line at 0 highlights the profitability threshold, making it easy to see which seasons tend to be profitable or loss-making, and the spread of profits.

# %% [markdown]
# ## Step 12: Crop-Wise Analysis

# %% [markdown]
# **Average yield for each crop**

# %%
df.groupby('Crop')['Yield_Tonnes_Ha'].mean().sort_values(ascending=False)
# Out:
# Crop
# Sugarcane   (x:,.2f)
# Maize       (x:,.2f)
# Rice        (x:,.2f)
# Wheat       (x:,.2f)
# Chilli      (x:,.2f)
# Groundnut   (x:,.2f)
# Cotton      (x:,.2f)
# Pulses      (x:,.2f)
# Name: Yield_Tonnes_Ha, dtype: float64

# %% [markdown]
# This command groups the DataFrame by 'Crop' and calculates the mean 'Yield_Tonnes_Ha' for each crop, then sorts the results in descending order. This helps in identifying the highest yielding crops.

# %% [markdown]
# **Bar chart of crop-wise yield**

# %%
df.groupby('Crop')['Yield_Tonnes_Ha'].mean().sort_values().plot(kind='barh', color='teal')
plt.title('Average Yield by Crop')
plt.xlabel('Yield (Tonnes/Ha)')
plt.show()

# %% [markdown]
# This code generates a horizontal bar chart to visualize the average yield for each crop, sorted from lowest to highest. This makes it easy to compare the productivity of different crops.

# %% [markdown]
# ## Step 13: State-Wise Analysis

# %%
df.groupby('State')['Profit_INR'].mean().sort_values(ascending=False)
# Out:
# State
# Punjab           (x:,.2f)
# Maharashtra      (x:,.2f)
# Karnataka        (x:,.2f)
# Tamil Nadu       (x:,.2f)
# Gujarat          (x:,.2f)
# Telangana        (x:,.2f)
# Madhya Pradesh   (x:,.2f)
# Andhra Pradesh   (x:,.2f)
# Name: Profit_INR, dtype: float64

# %% [markdown]
# This command groups the DataFrame by 'State' and calculates the mean 'Profit_INR' for each state, then sorts the results in descending order. This helps in identifying which states are most profitable for agriculture.

# %% [markdown]
# ## Step 14: Correlation Between Columns
#
# **df.corr() — check how strongly numeric columns are related to each other**

# %%
numeric_df = df[['Rainfall_mm', 'Avg_Temperature_C', 'Yield_Tonnes_Ha', 'Profit_INR', 'Water_Used_m3']]
numeric_df.corr()
# Out:
#                    Rainfall_mm  Avg_Temperature_C  Yield_Tonnes_Ha  \
# Rainfall_mm           (x:,.2f)           (x:,.2f)         (x:,.2f)
# Avg_Temperature_C     (x:,.2f)           (x:,.2f)         (x:,.2f)
# Yield_Tonnes_Ha       (x:,.2f)           (x:,.2f)         (x:,.2f)
# Profit_INR            (x:,.2f)           (x:,.2f)         (x:,.2f)
# Water_Used_m3         (x:,.2f)           (x:,.2f)         (x:,.2f)
#
#                    Profit_INR  Water_Used_m3
# Rainfall_mm          (x:,.2f)       (x:,.2f)
# Avg_Temperature_C    (x:,.2f)       (x:,.2f)
# Yield_Tonnes_Ha      (x:,.2f)       (x:,.2f)
# Profit_INR           (x:,.2f)       (x:,.2f)
# Water_Used_m3        (x:,.2f)       (x:,.2f)

# %% [markdown]
# This code first selects a subset of numeric columns and then calculates the pairwise correlation between them. Correlation measures the strength and direction of a linear relationship between two variables. This helps understand how factors like rainfall, temperature, and water usage might influence yield and profit.

# %% [markdown]
# **Heatmap of the correlation**

# %%
plt.figure(figsize=(7,5))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# This code generates a heatmap to visually represent the correlation matrix calculated in the previous step. The `annot=True` displays the correlation values on the heatmap, and `cmap='coolwarm'` sets the color scheme, making it easy to spot strong positive (warm colors) and negative (cool colors) correlations.

# %% [markdown]
# ## Step 15: Finding Loss-Making Farms
#
# Count how many farms had negative profit (a loss) using simple conditions.

# %%
loss_farms = df[df['Profit_INR'] < 0]
print("Total loss-making farms:", len(loss_farms))
loss_farms.head()
# Out:
# Total loss-making farms: 1966
#    Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 0  SF10001  Andhra Pradesh    Rajkot   Wheat  Kharif            (x:,.2f)
# 1  SF10002     Maharashtra  Nalgonda   Maize  Kharif            (x:,.2f)
# 2  SF10003       Telangana  Warangal  Pulses    Rabi            (x:,.2f)
# 3  SF10004       Telangana    Indore    Rice  Kharif            (x:,.2f)
# 4  SF10005       Karnataka  Ludhiana   Maize    Zaid            (x:,.2f)
#
#    Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  Soil_pH  \
# 0     (x:,.2f)           (x:,.2f)      (x:,.2f)            (x:,.2f) (x:,.2f)
# 1     (x:,.2f)           (x:,.2f)      (x:,.2f)            (x:,.2f) (x:,.2f)
# 2     (x:,.2f)           (x:,.2f)      (x:,.2f)            (x:,.2f) (x:,.2f)
# 3     (x:,.2f)           (x:,.2f)      (x:,.2f)            (x:,.2f) (x:,.2f)
# 4     (x:,.2f)           (x:,.2f)      (x:,.2f)            (x:,.2f) (x:,.2f)
#
# ...

# %% [markdown]
# This code filters the DataFrame to select only those farms where 'Profit_INR' is less than 0, indicating a loss. It then prints the total count of such farms and displays the first 5 rows of this filtered DataFrame. This helps in identifying and analyzing loss-making operations.

# %%
loss_farms['Season'].value_counts()
# Out:
# Season
# Rabi      832
# Kharif    751
# Zaid      383
# Name: count, dtype: int64

# %% [markdown]
# This command counts the number of loss-making farms (`loss_farms`) categorized by 'Season'. It helps in understanding which seasons contribute most to agricultural losses.

# %% [markdown]
# ## Step 16: Sorting Data
#
# **sort_values() — find the top 5 highest profit farms**

# %%
df.sort_values(by='Profit_INR', ascending=False).head()
# Out:
#       Farm_ID           State  District       Crop  Season  \
# 2236  SF12237          Punjab    Rajkot     Chilli  Kharif
# 626   SF10627     Maharashtra  Warangal     Chilli  Kharif
# 3425  SF13426  Madhya Pradesh    Rajkot  Sugarcane  Kharif
# 1690  SF11691       Karnataka  Warangal     Chilli  Kharif
# 247   SF10248     Maharashtra   Krishna     Chilli  Kharif
#
#       Farm_Area_Hectares  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# 2236            (x:,.2f)     (x:,.2f)           (x:,.2f)      (x:,.2f)
# 626             (x:,.2f)     (x:,.2f)           (x:,.2f)      (x:,.2f)
# 3425            (x:,.2f)     (x:,.2f)           (x:,.2f)      (x:,.2f)
# 1690            (x:,.2f)     (x:,.2f)           (x:,.2f)      (x:,.2f)
# 247             (x:,.2f)     (x:,.2f)           (x:,.2f)      (x:,.2f)
#
#       Sunlight_Hours_Day  Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  \
# 2236            (x:,.2f) (x:,.2f)           (x:,.2f)        (x:,.2f)
# ...

# %% [markdown]
# This command sorts the entire DataFrame `df` by the 'Profit_INR' column in descending order and displays the top 5 rows. This effectively shows the 5 farms with the highest profits.

# %% [markdown]
# **Find the 5 lowest profit (biggest loss) farms**

# %%
df.sort_values(by='Profit_INR').head()
# Out:
#       Farm_ID           State  District       Crop  Season  \
# 780   SF10781  Andhra Pradesh  Ludhiana  Groundnut    Rabi
# 2210  SF12211  Andhra Pradesh   Raichur      Wheat    Rabi
# 3625  SF13626          Punjab   Krishna      Maize    Rabi
# 2182  SF12183  Andhra Pradesh   Krishna       Rice  Kharif
# 104   SF10105         Gujarat   Krishna      Wheat    Zaid
#
#       Farm_Area_Hectares  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# 780             (x:,.2f)     (x:,.2f)           (x:,.2f)      (x:,.2f)
# 2210            (x:,.2f)     (x:,.2f)           (x:,.2f)      (x:,.2f)
# 3625            (x:,.2f)     (x:,.2f)           (x:,.2f)      (x:,.2f)
# 2182            (x:,.2f)     (x:,.2f)           (x:,.2f)      (x:,.2f)
# 104             (x:,.2f)     (x:,.2f)           (x:,.2f)      (x:,.2f)
#
#       Sunlight_Hours_Day  Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  \
# 780             (x:,.2f) (x:,.2f)           (x:,.2f)        (x:,.2f)
# ...

# %% [markdown]
# This command sorts the entire DataFrame `df` by the 'Profit_INR' column in ascending order and displays the top 5 rows. This effectively shows the 5 farms with the lowest profits (i.e., the biggest losses).

# %% [markdown]
# ## Step 17: Conclusion
#
# Based on this basic analysis:
#
# 1. **Kharif season** has the highest average rainfall, yield, and profit among the three seasons.
# 2. **Zaid season** has the lowest average profit, and many Zaid farms are loss-making.
# 3. **Rabi season** performs in between Kharif and Zaid.
# 4. Crops and states show different average yield and profit, which can guide future planning.
# 5. Simple pandas commands like `head()`, `describe()`, `groupby()`, and `corr()` are enough to
#    uncover clear, useful seasonal patterns in agricultural data.
#
# ### Recommendations
# - Farmers should be encouraged to plan major crops around the Kharif season for better returns.
# - Zaid season farming needs better irrigation support since rainfall is lowest in that season.
# - Further study can be done using more years of data to confirm these seasonal patterns.

# %% [markdown]
# ## **Project Analysis: Expected Outcomes & Key Questions**
#
# ### **Outcome 1: Discover Relationships and Variations (Environmental vs Performance)**
# **Key Question:** Are there relationships between seasonal environmental conditions and agricultural performance?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Using 'df' created in earlier steps.
# Ensure Step 2 has been executed after uploading the file.
if 'df' in locals():
    plt.figure(figsize=(12, 6))
    sns.scatterplot(data=df, x='Soil_Moisture_pct', y='Production_Tonnes', hue='Season', alpha=0.6)
    plt.title('Relationship between Soil Moisture and Production by Season')
    plt.show()

    # Calculate correlation for each season specifically
    for season in df['Season'].unique():
        season_data = df[df['Season'] == season][['Avg_Temperature_C', 'Yield_Tonnes_Ha']].dropna()
        if not season_data.empty:
            corr = season_data.corr().iloc[0,1]
            print(f"Correlation between Temp and Yield in {season}: {corr:.2f}")
else:
    print("Error: DataFrame 'df' not found. Please upload the dataset and run Step 2 first.")
# Out:
# Correlation between Temp and Yield in Kharif: -0.01
# Correlation between Temp and Yield in Rabi: 0.05
# Correlation between Temp and Yield in Zaid: -0.04

# %% [markdown]
# ### **Outcome 2: Compare Agricultural Performance Across Regions/Groups**
# **Key Question:** Are some seasonal patterns consistent across different regions?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

if 'df' in locals():
    plt.figure(figsize=(14, 7))
    state_season_profit = df.groupby(['State', 'Season'])['Profit_INR'].mean().unstack()
    state_season_profit.plot(kind='bar', figsize=(14,7))
    plt.title('Average Profit by State and Season')
    plt.ylabel('Profit (INR)')
    plt.xticks(rotation=45)
    plt.legend(title='Season')
    plt.tight_layout()
    plt.show()
else:
    print("Error: DataFrame 'df' not found.")

# %% [markdown]
# ### **Outcome 3: Identify Significant Observations & Unusual Patterns**
# **Key Question:** Are there noticeable variations in resource usage (Water Efficiency) across seasons?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

if 'df' in locals():
    # Analyzing Water Efficiency
    plt.figure(figsize=(10, 6))
    sns.violinplot(x='Season', y='Water_Efficiency_t_per_1000m3', data=df)
    plt.title('Distribution of Water Efficiency across Seasons')
    plt.show()

    # Identifying outliers (Unusual Patterns)
    q_hi = df['Yield_Tonnes_Ha'].quantile(0.99)
    df_filtered = df[(df['Yield_Tonnes_Ha'] > q_hi)]
    print(f'Number of exceptionally high yield farms identified as anomalies: {len(df_filtered)}')
    display(df_filtered[['Farm_ID', 'Crop', 'Season', 'Yield_Tonnes_Ha']].head())
else:
    print("Error: DataFrame 'df' not found.")
# Out:
# Number of exceptionally high yield farms identified as anomalies: 40
#      Farm_ID       Crop  Season  Yield_Tonnes_Ha
# 222  SF10223  Sugarcane    Rabi         (x:,.2f)
# 298  SF10299  Sugarcane  Kharif         (x:,.2f)
# 357  SF10358  Sugarcane    Rabi         (x:,.2f)
# 644  SF10645  Sugarcane  Kharif         (x:,.2f)
# 811  SF10812  Sugarcane  Kharif         (x:,.2f)

# %% [markdown]
# ## Detailed Project Description
#
# This project, titled "Seasonal Agriculture Performance Analysis," aimed to investigate how agricultural performance (yield, profit, resource use) changes across the three main farming seasons in India: Kharif, Rabi, and Zaid. The analysis was conducted using basic data analytics techniques, leveraging a dataset that includes information on farming practices, environmental conditions, crop production, resource usage, and economic performance across various states and districts.
#
# ### 1. Problem Statement and Objectives
# The core problem identified was the lack of clear insights into how agricultural performance varies seasonally, despite the significant influence of environmental and market conditions. The project sought to analyze the provided agricultural dataset to identify meaningful patterns, trends, relationships, and variations in performance across different seasons. Key objectives included exploring and understanding the dataset, cleaning and preparing the data, examining seasonal variations, identifying patterns, investigating relationships between seasonal conditions and outcomes, comparing relevant groups, and applying statistical and visualization techniques to interpret findings and develop data-driven recommendations.
#
# ### 2. Dataset
# The analysis utilized the `seasonal_agriculture_performance_dataset.xlsx` file, which contains 4000 entries across 28 columns, covering diverse agricultural activities.
#
# ### 3. Data Loading and Initial Understanding (Steps 1-3)
#
# **Step 1: Importing Libraries**
# Essential Python libraries were imported for data manipulation (`pandas`, `numpy`) and data visualization (`matplotlib.pyplot`, `seaborn`), setting up the environment for analysis.
#
# **Step 2: Loading the Dataset**
# The `seasonal_agriculture_performance_dataset.xlsx` file was loaded into a pandas DataFrame named `df`. Initial display of the DataFrame showed its structure and content.
#
# **Step 3: Initial Data Understanding**
# Various pandas commands were used to get a preliminary understanding of the dataset:
# - `df.head()`: Displayed the first 5 rows to quickly glimpse the data's structure and values.
# - `df.tail()`: Showed the last 5 rows, confirming complete data loading.
# - `df.sample(5)`: Provided 5 random rows for a generalized view of the data.
# - `df.shape`: Revealed the DataFrame has 4000 rows and 28 columns.
# - `df.columns`: Listed all column names, aiding in feature identification.
# - `df.dtypes`: Displayed the data type of each column, crucial for data cleaning and type conversion.
# - `df.info()`: Presented a concise summary, including non-null counts and memory usage, highlighting columns with potential missing values.
# - `df.describe()`: Generated basic descriptive statistics for numerical columns, offering insights into central tendency, dispersion, and range of the data.

# %% [markdown]
# ### 4. Data Cleaning (Step 4 & 5)
#
# **Step 4: Check for Missing Values and Duplicates**
# - `df.isnull().sum()`: Identified missing values in `Rainfall_mm` (48), `Soil_Moisture_pct` (40), and `Yield_Tonnes_Ha` (32).
# - `df.duplicated().sum()`: Confirmed there were no duplicate rows in the dataset.
#
# **Step 5: Clean the Data**
# - Missing values in `Rainfall_mm`, `Soil_Moisture_pct`, and `Yield_Tonnes_Ha` were imputed by filling them with the mean of their respective columns. This approach preserves the central tendency of the data. A final check using `df.isnull().sum().sum()` confirmed that all missing values were successfully handled.

# %% [markdown]
# ### 5. Column Exploration (Step 6)
#
# **Step 6: Explore the Columns**
# Key categorical columns were explored to understand their unique values and distributions:
# - `df['Season'].unique()`: Revealed three distinct seasons: 'Kharif', 'Rabi', 'Zaid'.
# - `df['Season'].value_counts()`: Showed the distribution of farms across seasons (Kharif: 1779, Rabi: 1627, Zaid: 594).
# - `df['Crop'].unique()`: Listed the 8 different crops in the dataset (Wheat, Maize, Pulses, Rice, Cotton, Chilli, Groundnut, Sugarcane).
# - `df['State'].unique()`: Identified 8 different states covered by the data.

# %% [markdown]
# ### 6. Basic Visualization and Season-Wise Analysis (Steps 7-9)
#
# **Step 7: Basic Visualization — Season Distribution**
# - A bar plot was generated to visually represent the `value_counts()` of the 'Season' column, clearly showing the number of farms in each season.
#
# **Step 8: Average Values Season-Wise**
# - The DataFrame was grouped by 'Season' to calculate mean values for key performance indicators:
#     - `Yield_Tonnes_Ha`: Kharif showed the highest average yield (5.64 tonnes/Ha), followed by Rabi (5.08) and Zaid (4.67).
#     - `Profit_INR`: Kharif had the highest average profit (178,914 INR), Rabi was second (87,689 INR), while Zaid recorded an average loss (-24,804 INR).
#     - `Rainfall_mm`: Kharif experienced the highest average rainfall (849.4 mm), followed by Rabi (437.8 mm) and Zaid (305.0 mm).
#     - `Water_Used_m3`: Zaid season had the highest average water usage (6419.89 m3), despite having the lowest rainfall.
#
# **Step 9: Visualize Season-Wise Averages**
# - Bar charts were created for average yield, profit, and rainfall by season, providing clear visual comparisons. The profit chart included a horizontal line at 0 to highlight loss-making seasons.

# %% [markdown]
# ### 7. Distribution Analysis and Crop/State Analysis (Steps 10-13)
#
# **Step 10: Boxplot to Compare Yield Across Seasons**
# - A boxplot illustrated the distribution of `Yield_Tonnes_Ha` by season, showing the median, quartiles, and outliers, confirming Kharif's higher median yield and wider distribution.
#
# **Step 11: Boxplot to Compare Profit Across Seasons**
# - A boxplot for `Profit_INR` by season, with a zero-profit line, visually confirmed that Zaid season had a significant portion of its profit distribution below zero, indicating consistent losses.
#
# **Step 12: Crop-Wise Analysis**
# - The average yield for each crop was calculated and sorted, revealing Sugarcane as the highest-yielding crop (46.67 tonnes/Ha) by a significant margin.
# - A horizontal bar chart visualized these crop-wise yields.
#
# **Step 13: State-Wise Analysis**
# - Average profit per state was calculated and sorted, indicating Punjab and Maharashtra as the most profitable states for agriculture.

# %% [markdown]
# ### 8. Correlation and Loss-Making Farms (Steps 14-16)
#
# **Step 14: Correlation Between Columns**
# - A subset of relevant numerical columns (`Rainfall_mm`, `Avg_Temperature_C`, `Yield_Tonnes_Ha`, `Profit_INR`, `Water_Used_m3`) was selected to calculate their pairwise correlation.
# - A heatmap was generated to visually represent these correlations. Key observations from the heatmap include a moderately strong positive correlation between `Yield_Tonnes_Ha` and `Profit_INR` (0.488), and a weaker positive correlation between `Rainfall_mm` and `Profit_INR` (0.108).
#
# **Step 15: Finding Loss-Making Farms**
# - Farms with `Profit_INR` less than 0 were identified as loss-making. There were 1966 such farms.
# - An analysis of these loss-making farms by season showed that Rabi had the most (832), followed by Kharif (751), and Zaid (383).
#
# **Step 16: Sorting Data**
# - The DataFrame was sorted by `Profit_INR` to identify:
#     - The top 5 highest profit farms.
#     - The 5 lowest profit (biggest loss) farms.

# %% [markdown]
# ### 9. Conclusion and Recommendations (Step 17)
#
# **Conclusion:**
# 1.  **Kharif season** consistently showed the highest average rainfall, yield, and profit.
# 2.  **Zaid season** was identified as the least profitable, with many farms incurring losses.
# 3.  **Rabi season** performance was intermediate between Kharif and Zaid.
# 4.  Significant variations in average yield and profit were observed across different crops and states, providing potential avenues for optimized planning.
# 5.  Basic pandas commands and visualizations proved effective in revealing clear seasonal agricultural patterns.
#
# **Recommendations:**
# -   Farmers should be encouraged to prioritize major crops during the Kharif season to maximize returns.
# -   Addressing the low rainfall in the Zaid season through improved irrigation support is crucial to mitigate losses.
# -   Further research using multi-year data is recommended to validate and strengthen these seasonal patterns and trends.
